# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.family"] = "Times New Roman"     #全体のフォントを設定
plt.rcParams["font.size"] = 12                      #フォントの大きさ
plt.rcParams["xtick.direction"] = "out"              #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "out"  
plt.rcParams["axes.linewidth"] = 1.0                #囲みの太さ
plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = (6, 4)


# UTS

labels = ['LIN', 'SVR', 'RFR', 'GBR']
training = [0.5234277655864482 ,0.7280129247918885 ,0.740268494973833, 0.7128779879610406]
test = [0.5413967046417465, 0.5418208489003216, 0.5243440877120196, 0.40909684572886096]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, training, width, label='Training', color='blue', alpha=0.7, edgecolor='black')
rects2 = ax.bar(x + width/2, test, width, label='Test', color='red', alpha=0.7, edgecolor='black')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('R')
ax.set_xlabel('Models')
ax.set_ylim(0, 1.0)
# ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.savefig('comparison_R_UTS.png', bbox_inches="tight", pad_inches=0.05)

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()
# plt.savefig('comparison_R_UTS.png', bbox_inches="tight", pad_inches=0.05)
plt.show()
# plt.savefig('comparison_R.png', bbox_inches="tight", pad_inches=0.05)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-87d643c09c47> in <module>
#      35 plt.savefig('comparison_R_UTS.png', bbox_inches="tight", pad_inches=0.05)
#      36
# ---> 37 ax.bar_label(rects1, padding=3)
#      38 ax.bar_label(rects2, padding=3)
#      39
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %% [markdown]
# # ELongation

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.family"] = "Times New Roman"     #全体のフォントを設定
plt.rcParams["font.size"] = 12                      #フォントの大きさ
plt.rcParams["xtick.direction"] = "out"              #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "out"  
plt.rcParams["axes.linewidth"] = 1.0                #囲みの太さ
plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = (6, 4)


# Elongation

labels = ['LIN', 'SVR', 'RFR', 'GBR']
training = [0.75728382753369, 0.7382053700408472, 0.9110592095547753, 0.9984090591960296]
test = [0.46825338812473816, 0.5806907764218658, 0.5651409016847814, 0.8173527938885781]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, training, width, label='Training', color='blue', alpha=0.7, edgecolor='black')
rects2 = ax.bar(x + width/2, test, width, label='Test', color='red', alpha=0.7, edgecolor='black')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('R')
ax.set_xlabel('Models')
ax.set_ylim(0, 1.0)
# ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.savefig('comparison_R_elongation.png', bbox_inches="tight", pad_inches=0.05)

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()
plt.savefig('comparison_R_elongation.png', bbox_inches="tight", pad_inches=0.05)
# plt.savefig('comparison_R.png', bbox_inches="tight", pad_inches=0.05)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-5e071818db8a> in <module>
#      35 plt.savefig('comparison_R_elongation.png', bbox_inches="tight", pad_inches=0.05)
#      36
# ---> 37 ax.bar_label(rects1, padding=3)
#      38 ax.bar_label(rects2, padding=3)
#      39
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %% [markdown]
# # UTS MAE RMSE

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.family"] = "Times New Roman"     #全体のフォントを設定
plt.rcParams["font.size"] = 12                      #フォントの大きさ
plt.rcParams["xtick.direction"] = "out"              #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "out"  
plt.rcParams["axes.linewidth"] = 1.0                #囲みの太さ
plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = (6, 4)


# Elongation

labels = ['LIN', 'SVR', 'RFR', 'GBR']
MAE = [65.11798970268192, 62.839045917474465, 65.96986266076092, 76.48145186114994]
RMSE = [82.83533689854251, 82.7970224553042, 84.36134728842516, 94.0275697659288]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, MAE, width, label='MAE', color='darkorchid', alpha=0.7, edgecolor='black')
rects2 = ax.bar(x + width/2, RMSE, width, label='RMSE', color='darkcyan', alpha=0.7, edgecolor='black')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('MAE and RMSE')
ax.set_xlabel('Models')
ax.set_ylim(0, 120)
# ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.savefig('comparison_RMSE_UTS.png', bbox_inches="tight", pad_inches=0.05)

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-cbeebbecd576> in <module>
#      35 plt.savefig('comparison_RMSE_UTS.png', bbox_inches="tight", pad_inches=0.05)
#      36
# ---> 37 ax.bar_label(rects1, padding=3)
#      38 ax.bar_label(rects2, padding=3)
#      39
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.family"] = "Times New Roman"     #全体のフォントを設定
plt.rcParams["font.size"] = 12                      #フォントの大きさ
plt.rcParams["xtick.direction"] = "out"              #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "out"  
plt.rcParams["axes.linewidth"] = 1.0                #囲みの太さ
plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = (6, 4)


# Elongation

labels = ['LIN', 'SVR', 'RFR', 'GBR']
MAE = [4.417875502767742, 4.41143572934187, 3.039794367748954, 2.8491092079015554]
RMSE = [6.404904970325466, 5.6875801869775255, 4.226900142136039, 3.753762932748662]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, MAE, width, label='MAE', color='darkorchid', alpha=0.7, edgecolor='black')
rects2 = ax.bar(x + width/2, RMSE, width, label='RMSE', color='darkcyan', alpha=0.7, edgecolor='black')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('MAE and RMSE')
ax.set_xlabel('Models')
ax.set_ylim(0, 10)
# ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.savefig('comparison_RMSE_elongation.png', bbox_inches="tight", pad_inches=0.05)

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-741708fdd640> in <module>
#      35 plt.savefig('comparison_RMSE_elongation.png', bbox_inches="tight", pad_inches=0.05)
#      36
# ---> 37 ax.bar_label(rects1, padding=3)
#      38 ax.bar_label(rects2, padding=3)
#      39
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'
