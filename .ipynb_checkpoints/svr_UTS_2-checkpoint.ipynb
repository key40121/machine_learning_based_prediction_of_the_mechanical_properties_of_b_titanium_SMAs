# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from utils import *

plt.rcParams['figure.figsize'] = (6, 4)
plt.rcParams['figure.dpi'] = 300
plt.rcParams["font.family"] = "Times New Roman"     #全体のフォントを設定
plt.rcParams["font.size"] = 12 

df = pd.read_csv('../alldata.csv')

df_y = df[['UTS']]
df_X = df[['Ti', 'Mo_Equiavalent2', 'Delta', 'electronegativity', 'Bo', 'Cold Rolling Rate']]
X_train, X_test, y_train, y_test = train_test_split(df_X, df_y, stratify = df['stratify'], 
                                                    test_size=0.2, random_state=2361)

def model_evaluation(model):
    
    model.fit(X_train, y_train)
    predictions_test = model.predict(X_test)
    predictions_train = model.predict(X_train)

    print('r2 test:', r2_score(y_test, predictions_test))
    print('r2 train:',r2_score(y_train, predictions_train))

    print('MAE:', metrics.mean_absolute_error(y_test, predictions_test))
    print('MSE:', metrics.mean_squared_error(y_test, predictions_test))
    print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions_test)))

# %%
from sklearn.svm import SVR

reg_linear = SVR(kernel='linear', C=1, epsilon=0.1, gamma='auto')
reg_poly = SVR(kernel='poly', C=1, epsilon=0.1, gamma='auto')
reg_rbf = SVR(kernel='rbf', C=1, epsilon=0.1, gamma='auto')

reg_linear.fit(X_train, np.ravel(y_train))
reg_poly.fit(X_train, np.ravel(y_train))
reg_rbf.fit(X_train, np.ravel(y_train))
# Out:
# SVR(C=1, gamma='auto')

# %%
plot_UTS(reg_linear, df)
# Out:
# c:\users\ichis\.pyenv\pyenv-win\versions\3.8.2\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\dev\lab\python\20211229_thesis\implementation\utils.py:58: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
model_evaluation(reg_linear)
# Out:
# r2 test: 0.13054895999721428
# r2 train: 0.29212598329665174
# MAE: 94.2541623703322
# MSE: 13008.86018352874
# RMSE: 114.05639036690904
# c:\users\ichis\.pyenv\pyenv-win\versions\3.8.2\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %% [markdown]
# # linear

# %%
model1 = SVR(kernel='linear', C=1, epsilon=0.0,gamma='auto').fit(X_train, np.ravel(y_train))
model2 = SVR(kernel='linear', C=1, epsilon=0.1, gamma='auto').fit(X_train, np.ravel(y_train))
model3 = SVR(kernel='linear', C=1, epsilon=0.9, gamma='auto').fit(X_train, np.ravel(y_train))

scores = (model1.score(X_test, y_test), model2.score(X_test, y_test), model3.score(X_test, y_test))

plt.bar(("0.01", "1", "1000"), scores)
plt.xlabel("$C$")
plt.ylabel("$R^2$ score")
plt.show()

# %% [markdown]
# epsilon = 0.9

# %%
model1 = SVR(kernel='linear', C=100, epsilon=0.9,gamma='auto').fit(X_train, np.ravel(y_train))
model2 = SVR(kernel='linear', C=1000, epsilon=0.9, gamma='auto').fit(X_train, np.ravel(y_train))
model3 = SVR(kernel='linear', C=10000, epsilon=0.9, gamma='auto').fit(X_train, np.ravel(y_train))

scores = (model1.score(X_test, y_test), model2.score(X_test, y_test), model3.score(X_test, y_test))

plt.bar(("0.01", "1", "1000"), scores)
plt.xlabel("$C$")
plt.ylabel("$R^2$ score")
plt.show()

# %% [markdown]
# C = 10000

# %% [markdown]
# # RBFカーネル

# %%
model1 = SVR(kernel='rbf', C=1, epsilon=0.0,gamma='auto').fit(X_train, np.ravel(y_train))
model2 = SVR(kernel='rbf', C=1, epsilon=0.1, gamma='auto').fit(X_train, np.ravel(y_train))
model3 = SVR(kernel='rbf', C=1, epsilon=0.9, gamma='auto').fit(X_train, np.ravel(y_train))

scores = (model1.score(X_test, y_test), model2.score(X_test, y_test), model3.score(X_test, y_test))

plt.bar(("0.01", "1", "1000"), scores)
plt.xlabel("$C$")
plt.ylabel("$R^2$ score")
plt.show()

# %%
model1 = SVR(kernel='rbf', C=0.01, epsilon=0.9,gamma='auto').fit(X_train, np.ravel(y_train))
model2 = SVR(kernel='rbf', C=1, epsilon=0.9, gamma='auto').fit(X_train, np.ravel(y_train))
model3 = SVR(kernel='rbf', C=1000, epsilon=0.9, gamma='auto').fit(X_train, np.ravel(y_train))

scores = (model1.score(X_test, y_test), model2.score(X_test, y_test), model3.score(X_test, y_test))

plt.bar(("0.01", "1", "1000"), scores)
plt.xlabel("$C$")
plt.ylabel("$R^2$ score")
plt.show()

# %%
model1 = SVR(kernel='rbf', C=400, epsilon=0.9,gamma='auto').fit(X_train, np.ravel(y_train))
model2 = SVR(kernel='rbf', C=500, epsilon=0.9, gamma='auto').fit(X_train, np.ravel(y_train))
model3 = SVR(kernel='rbf', C=600, epsilon=0.9, gamma='auto').fit(X_train, np.ravel(y_train))

scores = (model1.score(X_test, y_test), model2.score(X_test, y_test), model3.score(X_test, y_test))

plt.bar(("0.01", "1", "1000"), scores)
plt.xlabel("$C$")
plt.ylabel("$R^2$ score")
plt.show()

# %%
model1 = SVR(kernel='rbf', C=500, epsilon=0.7,gamma='auto').fit(X_train, np.ravel(y_train))
model2 = SVR(kernel='rbf', C=500, epsilon=0.8, gamma='auto').fit(X_train, np.ravel(y_train))
model3 = SVR(kernel='rbf', C=500, epsilon=0.9, gamma='auto').fit(X_train, np.ravel(y_train))

scores = (model1.score(X_test, y_test), model2.score(X_test, y_test), model3.score(X_test, y_test))

plt.bar(("0.01", "1", "1000"), scores)
plt.xlabel("$C$")
plt.ylabel("$R^2$ score")
plt.show()

# %% [markdown]
# # C=500 epsilon=0.9

# %%
model = SVR(kernel='rbf', C=500, epsilon=0.9, gamma='auto').fit(X_train, np.ravel(y_train))
predictions_train = model.predict(X_train)
predictions_test = model.predict(X_test)

# %%
plt.rcParams["font.family"] = "Times New Roman"     #全体のフォントを設定
plt.rcParams["font.size"] = 12                      #フォントの大きさ
plt.rcParams["xtick.direction"] = "out"              #x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "out"  
plt.rcParams["axes.linewidth"] = 1.0                #囲みの太さ
plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = (6,4)

x = np.linspace(250, 900)
y = x

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line1 = ax.plot(x, y, c='black')
scatter2 = ax.scatter(y_train, predictions_train, c='blue', alpha=0.5, edgecolor='blue', linewidths=0.5, label='Measured UTS')
scatter1 = ax.scatter(y_test, predictions_test, c='red',marker="D",alpha=0.5, edgecolor='red', linewidths=0.5, label='Predicted UTS')


ax.set_xlim(250, 900)
ax.set_ylim(250, 900)
ax.legend()
# ax.set_title('Predicted UTS (by RF) vs. Measured UTS')
ax.set_xlabel('Measured UTS / MPa')
ax.set_ylabel('Predicted UTS / MPa')
plt.savefig('svr_rbf_UTS.png', bbox_inches="tight", pad_inches=0.05)
fig.show()
# Out:
# <ipython-input-33-473cc9601324>:26: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
model_evaluation(model)
# Out:
# r2 test: 0.5418208489003216
# r2 train: 0.7280129247918885
# MAE: 62.839045917474465
# MSE: 6855.3469274641475
# RMSE: 82.7970224553042
# c:\users\ichis\.pyenv\pyenv-win\versions\3.8.2\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
